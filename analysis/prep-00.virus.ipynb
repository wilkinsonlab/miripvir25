# %% [markdown]
# # prep.virus
#
# Virus were detected in a previous work (McLeish2024) using a BLAST-based pipeline. Because I don't have access to the original files but only a few datafiles provided by F., we need to convert the data from the format in which they were provided to a format that is useful for me. The final output rows contain:
#
# - library
# - acronym
# - taxid
# - scientific_name

# %%
import pandas as pd
import requests
from yaml import load, Loader
from daforfer import DaforferDB
conf = load(open("conf.yaml"), Loader)
db = DaforferDB(conf['database'])
db.toc()
# Out:
# ┌─────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │          name           │                                                                                  description                                                                                   │
# │         varchar         │                                                                                    varchar                                                                                     │
# ├─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ D_sites                 │ This table contains key information about each of the libraries, such as their site, habitat and host                                                                          │
# │ D_bacteriaHits          │ This table contains all the MOTUS hits obtained, regardless of their status. It contains the library where the detection took place, taxid, scientific name and the PAB labels │
# │ D_PABHits               │ This table contains all the PAB MOTUS hits. It contains the library where the detection took place, taxid, scientific name and the PAB labels                                  │
# │ d_TableS1               │ Table S1: Library sites and context                                                                                                                                            │
# │ D_PABOTUs               │ This table summarizes most of the information of our detected OTUs, including host_range, site_range, habitat_range, etc.                                                      │
# │ D_virusHits             │ This table contains all the virus hits. It contains the library where the detection took place, taxid, scientific name and the virus acronym                                   │
# │ D_coocDetections        │ Library code and number of cooccurring pairs detected                                                                                                                          │
# │ D_coocPairDetections    │ Number of cooccurring pairs per library. Deduplication can help assessing how many detections took place at library level                                                      │
# │ D_Site_level_div        │ Site-level diversity and number of cooccurring virus-bacteria                                                                                                                  │
# │ D_Habitat_level_div     │ Habitat-level diversity and number of cooccurring virus-bacteria                                                                                                               │
# │          ·              │                                ·                                                                                                                                               │
# │          ·              │                                ·                                                                                                                                               │
# │          ·              │                                ·                                                                                                                                               │
# │ T_coocHostRangeCorrBact │ Correlation test between number of cooccurrences and the host-range in Bacteria                                                                                                │
# │ T_coocHostRangeMW       │ Multiple Mann-Whitney tests on the Host-range of cooccurring organisms versus not cooccurring organisms                                                                        │
# │ P_PABtaxonomy           │ Number of PAB hits belonging to each different phylum and order                                                                                                                │
# │ D_PABTypeCounts         │ Occurrences of the different kinds of PABs                                                                                                                                     │
# │ T_coocByHabitat         │ Post-Hoc Mann Whitney U analysis on number of cooccurrennt pairs by habitat, group1 < group2                                                                                   │
# │ T_coocDivBySite         │ Correlation tests between species richness and number of coocurrences detected at each site                                                                                    │
# │ T_orgRangeslogRatioTest │ Power-law, Lognormal, and Exponential fit log-ratio test                                                                                                                       │
# │ T_orgRangeCorr          │ Regression between bacteria and virus range                                                                                                                                    │
# │ D_organismRange         │ Hosts bacteria and virus ranges                                                                                                                                                │
# │ T_hostCooc              │ Correlation test between possible cooccurences and detected cooccurences at host level                                                                                         │
# ├─────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 26 rows (20 shown)                                                                                                                                                                             2 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Assign NCBI taxon identifier to virus species

# %% [markdown]
# The file provided by Fernando requires some actions to turn it from its matrix form into a list of Library - Otu, which will be much easier to analyze later.
#
# We also have a metadata file (S4) that will allow us to assign a taxid to each viral species. To obtain taxon ids, we will need to query the NCBI api.

# %%
def extract_taxonomy_from_gene_records(host_name):
    url = "https://api.ncbi.nlm.nih.gov/datasets/v2"
    url = f'{url}/gene/accession/{host_name}/dataset_report'.replace(' ', '%20')
    r = requests.get(url)
    
    try: 
        r.raise_for_status()
    except requests.HTTPError:
        return pd.NA
    try:
        u = str(r.json()['reports'][0]['gene']['tax_id'])
    except KeyError:
        return pd.NA
    except IndexError:
        return pd.NA
    return u

# %% [markdown]
# Reading metadata (S4), which contains a few interesting attributes such as the NCBI accession that we will use to find taxids.

# %%
virus = pd.read_csv("input/mcleish24.TableS4.csv", sep=';')
virus['OTU_taxid'] = virus['NCBI_accession'].apply(extract_taxonomy_from_gene_records)
virus
# Out:
#                 OTU name          Family  \
# 0          Alfamovirus 1    Bromoviridae
# 1          Alfamovirus 1    Bromoviridae
# 2    Alphaendornavirus 1  Endornaviridae
# 3    Alphaendornavirus 2  Endornaviridae
# 4    Alphaendornavirus 3  Endornaviridae
# ..                   ...             ...
# 172            Comovirus     Secoviridae
# 173            Comovirus     Secoviridae
# 174      Varicosavirus 1   Rhabdoviridae
# 175      Varicosavirus 1   Rhabdoviridae
# 176      Varicosavirus 2   Rhabdoviridae
#
#                                   NCBI_title OTU_reference    Genome  \
# 0                 Alfalfa mosaic virus RNA 1          AMV1  (+)ssRNA
# 1                 Alfalfa mosaic virus RNA 2          AMV2  (+)ssRNA
# 2                  Cucumis melo endornavirus          CmEV     dsRNA
# 3                   Bell pepper endornavirus          BPEV     dsRNA
# 4               Hordeum vulgare endornavirus          HvEV     dsRNA
# ..                                       ...           ...       ...
# 172          Arabidopsis latent virus-1 RNA1         ALaV1  (+)ssRNA
# 173          Arabidopsis latent virus-1 RNA2         ALaV2  (+)ssRNA
# 174  Lettuce big-vein associated virus RNA 1        LBVaV1  (-)ssRNA
# 175  Lettuce big-vein associated virus RNA 2        LBVaV2  (-)ssRNA
# 176              Lettuce yellow mottle virus         LYMoV  (-)ssRNA
#
#      %_ID_mean  %_ID_min  %_ID_max  BLAST_matches NCBI_accession OTU_taxid
# 0         96.6      94.4      99.2              4      NC_001495     12321
# 1         94.1      94.1      94.1              2      NC_002024     12321
# 2         96.5      87.9     100.0           4174      NC_029064   1776177
# 3        100.0     100.0     100.0              2      NC_015781      <NA>
# 4         96.6      87.2     100.0           4002      NC_028949   1774276
# ..         ...       ...       ...            ...            ...       ...
# 172       99.5      97.3     100.0             52       MH899120      <NA>
# 173       97.6      94.0     100.0             30       MH899121      <NA>
# 174       95.3      93.3      97.3             12      NC_011558   1985698
# 175       94.9      90.6      98.0             32      NC_011568   1985698
# 176       96.2      85.3     100.0           2702      NC_011532    471285
#
# [177 rows x 11 columns]

# %% [markdown]
# ## Load processed Virus hits

# %% [markdown]
# Now we load the original data. As it is formated as a matrix, we will need to melt it into a 1-row-1-detection dataframe.

# %%
hits = pd.read_csv("input/val_158_otu_host_df.csv", sep=';')
hits = hits.melt(
    id_vars=['Library', 'Host', 'Host_family', 'Habitat', 'Site', 'Collection'],
    value_vars=hits.columns[6:], 
).rename(columns={'variable': "OTU", 'value': "hit"}).query('hit == 1').copy()
hits['Collection'] = hits['Collection'].apply(lambda x: x.split("_")[0])
hits[['Library', 'Host', 'Host_family', 'Habitat', 'Site', 'Collection', 'OTU']]
# Out:
#       Library                  Host     Host_family    Habitat Site  \
# 74      PV091          Galium verum       Rubiaceae        Oak   Q4
# 332     PV059         Tragopogon sp      Asteraceae  Wasteland   E4
# 425     PV159    Carduus bourgeanus      Asteraceae       Edge   L1
# 448     PV182      Lactuca serriola      Asteraceae       Edge   L3
# 537     PV498       Rubia peregrina       Rubiaceae       Crop   H3
# ...       ...                   ...             ...        ...  ...
# 44458   PV172      Picris echioides      Asteraceae       Edge   L2
# 44487   PV201  Convolvulus arvensis  Convolvulaceae       Edge   L1
# 44625   PV047              Zea mays         Poaceae       Crop   Z2
# 44638   PV061          Cucumis melo   Cucurbitaceae       Crop   M1
# 44781   PV211        Solanum nigrum      Solanaceae       Edge   L2
#
#       Collection   OTU
# 74           Q4P  AEV1
# 332          E4P  AEYV
# 425          L1V  AEYV
# 448          L3V  AEYV
# 537          H3P  AEYV
# ...          ...   ...
# 44458        L2V   YSV
# 44487        L1F   YSV
# 44625        Z2V  ZYMV
# 44638        M5V  ZYMV
# 44781        L2F  ZYMV
#
# [1616 rows x 7 columns]

# %% [markdown]
# ## Rename hits

# %% [markdown]
# To merge S4 and this file, we need to use a handcrafted dictionary (`mapping-otus-curated.csv`).

# %%
rename_map = pd.read_csv("input/mapping-otus-curated.csv", sep="\t", index_col=0)[['otu', 'hit']].set_index('otu').to_dict()['hit']
hits['OTU_rn'] = hits['OTU'].apply(lambda x: rename_map[x])
hits[hits['OTU_rn'].isna()][['OTU']].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Final merge

# %% [markdown]
# Finally, we merge the two files.

# %%
virus_hits = pd.merge(hits, virus, left_on='OTU_rn', right_on='OTU_reference', how='left')[['Library', 'OTU_reference', 'OTU_taxid', 'NCBI_title']]
virus_hits = virus_hits.rename(
    columns={'Library': 'library', 'OTU_reference': 'acronym', 'OTU_taxid': 'taxid', 'NCBI_title': 'scientific_name'}
).sort_values(by=['library', 'acronym'])
virus_hits
# Out:
#      library     acronym    taxid                      scientific_name
# 300    PV001        CMV3    12305          Cucumber mosaic virus RNA 3
# 286    PV001        CmEV  1776177            Cucumis melo endornavirus
# 529    PV001       GMMV3   578305   Gayfeather mild mottle virus RNA 3
# 937    PV001       RuCMV   378833         Rubus chlorotic mottle virus
# 301    PV002        CMV3    12305          Cucumber mosaic virus RNA 3
# ...      ...         ...      ...                                  ...
# 515    PV589    CYDV_RPV  2170100      Cereal yellow dwarf virus - RPV
# 1575   PV589    WYDV_GPV   572239       Wheat yellow dwarf virus - GPV
# 488    PV590  CMV_satRNA     <NA>  Cucumber mosaic virus satellite RNA
# 1047   PV590       RuCMV   378833         Rubus chlorotic mottle virus
# 1418   PV590        ToMV    12253                  Tomato mosaic virus
#
# [1616 rows x 4 columns]

# %% [markdown]
# ## Save

# %%
virus_hits.to_csv("output/hits.virus.csv", sep=";", index=None)

# %%
db.save_dataframe(
    virus_hits, table_name="D_virusHits", 
    description="This table contains all the virus hits. It contains the library where the detection took place, taxid, scientific name and the virus acronym"
)
# Out:
# Saved D_virusHits to db.2025-11-17

# %%
db.conn.close()
