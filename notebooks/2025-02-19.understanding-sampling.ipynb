# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
samples = pd.read_excel("../data/McLeish24.sup_file.xlsx", sheet_name="Table_S2")
samples
# Out:
#     Library code            Host taxon Habitat Collection code  No. extracts
# 0          PV001         Amaranthus sp    Crop             M1V             8
# 1          PV002  Convolvulus arvensis    Crop             M1V            11
# 2          PV003          Cucumis melo    Crop             M1V            13
# 3       PV003bgi          Cucumis melo    Crop             M1V            13
# 4       PV004bgi        Cyperus longus    Crop             M1V             7
# ..           ...                   ...     ...             ...           ...
# 318        PV586    Fumaria parviflora    Crop             H1P             8
# 319        PV587   Hirschfeldia incana    Crop             H1P             8
# 320        PV588       Hordeum vulgare    Crop             H1P             8
# 321        PV589       Hordeum vulgare    Crop             H1P             8
# 322        PV590              Zea mays    Crop             Z1V            11
#
# [323 rows x 5 columns]

# %%
samples.value_counts('Host taxon').head()
# Out:
# Host taxon
# Convolvulus arvensis    14
# Diplotaxis erucoides    11
# Picris echioides        10
# Rubia peregrina          9
# Carduus bourgeanus       9
# Name: count, dtype: int64

# %%
samples.value_counts('Host taxon').tail()
# Out:
# Host taxon
# Portulaca oleraceae    1
# Potentilla sp          1
# Cyperus longus         1
# Crataegus monogyna     1
# Allium sativum         1
# Name: count, dtype: int64

# %%
len(samples['Host taxon'].unique())
# Out:
# 119

# %%
sns.catplot(y='Host taxon', x='count', data=samples.value_counts('Host taxon').reset_index(), height=14, aspect=0.4, hue='Host taxon', kind='bar')

# %%
len(samples['Collection code'].unique())
# Out:
# 46
